# %% [markdown]
# <div style="background-color:Pink; padding:10px; border-radius:5px; border:1px solid black;">
#     <h1 style="color:black; text-align:center;">Predicting Pneumonia in Chest X-Ray Images</h1>
#     <h3 style="color:black; text-align:center;">An exploration on the efficacy of different modeling techniques</h3>
#     <h3 style="color:gray; text-align:center;">CNN Modeling</h3>
# </div>

# %% [markdown]
# ## Step 0: Import Modules
#
# ---

# %%
import tensorflow as tf
import pandas as pd
import seaborn as sns
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array, apply_affine_transform
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, GlobalAveragePooling2D
from PIL import Image
from tensorflow.keras.applications import VGG16, DenseNet121
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import roc_auc_score, roc_curve
tf.random.set_seed(42)

# %% [markdown]
# ## Step 1: Load Dataset
#
# ---

# %% [markdown]
# We load the datasets containing the file paths to the cleaned and prepared images. We pick a standard 256 by 256 pixel format for the images and a standard but smaller batch size of 16.
#
# PNEUMONIA cases are recoded to 1s as strings and NORMAL cases are recoded to 0s as strings. This is for formating in the ImageDataGenerator process.

# %%
# Set image dimensions
IMG_SIZE = (256, 256)
BATCH_SIZE = 16

# Load CSV files containing cleaned image paths and labels
train_df = pd.read_csv("data/train_data_cleaned.csv")
test_df = pd.read_csv("data/test_data_cleaned.csv")
val_df = pd.read_csv("data/val_data_cleaned.csv")

# Convert labels to binary: 0 = NORMAL, 1 = PNEUMONIA
train_df['label'] = train_df['label'].map({'NORMAL': 0, 'PNEUMONIA': 1}).astype(str)
val_df['label'] = val_df['label'].map({'NORMAL': 0, 'PNEUMONIA': 1}).astype(str)
test_df['label'] = test_df['label'].map({'NORMAL': 0, 'PNEUMONIA': 1}).astype(str)

# Verify the conversion
print(train_df['label'].value_counts(normalize = True))
# Out:
# label
# 1    0.741811
# 0    0.258189
# Name: proportion, dtype: float64

# %% [markdown]
# Most of our cases are labeled PNEUMONIA, however as previously discussed we can use this imbalance to our advantage to prevent more false negatives in favor of false positives. This is favorable due to the healthcare context.

# %% [markdown]
# ### Step 1.1: Data Augmentation and Image Generator

# %% [markdown]
# Here we build out the ImageDataGenerator with some small data augmentation. We don't want to augment too much because we don't want to destroy the information contained in the X-rays, we simply want to add variation so the network does not completely memorize the training data.

# %%
# Augmentation for training images
train_datagen = ImageDataGenerator(
    rescale=1./255,               # Normalize pixel values
    rotation_range=10,            # Random rotations up to 10 degrees
    width_shift_range=0.1,        # Horizontal shift up to 10%
    height_shift_range=0.1,       # Vertical shift up to 10%
    zoom_range=0.1,               # Slight zoom in/out
    brightness_range=[0.9, 1.1],  # Adjust brightness slightly
    fill_mode='constant'
)

# Only rescaling for validation/test images
test_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

# %% [markdown]
# ### Step 1.2: Custom CNN Data Generators

# %%
train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='image_path',
    y_col='label',
    target_size=IMG_SIZE,
    color_mode='grayscale',  # load images as grayscale
    class_mode='binary',
    batch_size=BATCH_SIZE,
    shuffle=True,
    keep_aspect_ratio=True
)

val_generator = test_datagen.flow_from_dataframe(
    dataframe=val_df,
    x_col='image_path',
    y_col='label',
    target_size=IMG_SIZE,
    color_mode='grayscale',
    class_mode='binary',
    batch_size=BATCH_SIZE,
    shuffle=False,
    keep_aspect_ratio=True
)

test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col='image_path',
    y_col='label',
    target_size=IMG_SIZE,
    color_mode='grayscale',
    class_mode='binary',
    batch_size=BATCH_SIZE,
    shuffle=False,
    keep_aspect_ratio=True
)
# Out:
# Found 5190 validated image filenames belonging to 2 classes.
# Found 16 validated image filenames belonging to 2 classes.
# Found 618 validated image filenames belonging to 2 classes.

# %% [markdown]
# ### Step 1.3: Pretrained CNN Data Generators

# %%
train_generator_rgb = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='image_path',
    y_col='label',
    target_size=IMG_SIZE,
    color_mode='rgb',  # load images as RGB for pretrained networks
    class_mode='binary',
    batch_size=BATCH_SIZE,
    shuffle=True,
    keep_aspect_ratio=True
)

val_generator_rgb = test_datagen.flow_from_dataframe(
    dataframe=val_df,
    x_col='image_path',
    y_col='label',
    target_size=IMG_SIZE,
    color_mode='rgb',
    class_mode='binary',
    batch_size=BATCH_SIZE,
    shuffle=False,
    keep_aspect_ratio=True
)

test_generator_rgb = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col='image_path',
    y_col='label',
    target_size=IMG_SIZE,
    color_mode='rgb',
    class_mode='binary',
    batch_size=BATCH_SIZE,
    shuffle=False,
    keep_aspect_ratio=True
)
# Out:
# Found 5190 validated image filenames belonging to 2 classes.
# Found 16 validated image filenames belonging to 2 classes.
# Found 618 validated image filenames belonging to 2 classes.

# %% [markdown]
# ### Step 1.4: Sample Augmented Images

# %%
x_batch, y_batch = next(train_generator)  # get one batch of augmented images
plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.imshow(x_batch[i].squeeze(), cmap='gray')
    plt.title(f"Label: {y_batch[i]}")
    plt.axis("off")
plt.suptitle("Augmented X-ray Images")
plt.tight_layout()
plt.savefig("images/augmented_x_ray_images.png")
plt.show()

# %% [markdown]
# Now that we have uploaded the dataset containing the cleaned image paths, built a ImageDataGenerator, and data generators (train, test, and validation), we can move on to building out our first CNN.

# %% [markdown]
# ## Step 2: Build CNN from Scratch
#
# ---

# %% [markdown]
# ### Step 2.1: CNN Architecture
#
# - First Convolutional Block
#     - 64 filters, ReLU activation, L2 Regularization (to prevent overfitting)
#     - Pooling layer
# - Second Convolutional Block
#     - 128 filters, ReLU activation, L2 Regulatization (to prevent overfitting)
#     - Pooling Layer
# - Third Convolutional Block
#     - 256 filters, ReLU activation, L2 Regularization (to prevent overfitting)
#     - Pooling Layer
# - Flattening Layer
# - Fully Connected Dense Layer
#     - 256 neurons, ReLU activation, L2 Regularization (to prevent overfitting)
# - Dropout
#     - 50% of neurons dropped to prevent overfitting
# - Output Layer
#     - Single sigmoid neuron
#
# This is just a simple CNN I built based off of similar architecture I found through some quick research. The regularization techniques were added as I noticed the function learning too quickly and overfitting on the training set.
#
# Lastly, I used a dynamic learning rate that reduced everytime the testing loss did not improve for 3 iterations.

# %%
# Define Model with Regularization
cnn_model = Sequential([
    Conv2D(64, (3,3), activation='relu', kernel_regularizer=l2(0.01)),
    MaxPooling2D(2,2),
    Conv2D(128, (3,3), activation='relu', kernel_regularizer=l2(0.01)),
    MaxPooling2D(2,2),
    Conv2D(256, (3,3), activation='relu', kernel_regularizer=l2(0.01)),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(256, activation='relu', kernel_regularizer=l2(0.01)),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

cnn_model.build(input_shape = (train_generator.n, IMG_SIZE[0], IMG_SIZE[1], 1))

# Compile Model with Lower LR
cnn_model.compile(
    optimizer=Adam(learning_rate=0.00005),  # 🔽 Lower learning rate
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# Define Callbacks
lr_reduction = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=3, min_lr=1e-6)

# Train CNN using augmented dataset
cnn_model_history = cnn_model.fit(
    train_generator,
    validation_data=test_generator,
    epochs=40,
    callbacks=[lr_reduction]
)
# Out:
# 2025-03-19 23:50:30.946561: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3 Pro
# 2025-03-19 23:50:30.946651: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 18.00 GB
# 2025-03-19 23:50:30.946659: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 6.00 GB
# 2025-03-19 23:50:30.946707: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-03-19 23:50:30.946738: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/40
# 2025-03-19 23:50:31.587450: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 61s 185ms/step - accuracy: 0.7245 - loss: 4.4516 - val_accuracy: 0.6748 - val_loss: 1.7244 - learning_rate: 5.0000e-05
# Epoch 2/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 184ms/step - accuracy: 0.7496 - loss: 1.4899 - val_accuracy: 0.8074 - val_loss: 1.0670 - learning_rate: 5.0000e-05
# Epoch 3/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 184ms/step - accuracy: 0.8258 - loss: 0.9839 - val_accuracy: 0.8010 - val_loss: 0.8670 - learning_rate: 5.0000e-05
# Epoch 4/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.8766 - loss: 0.7457 - val_accuracy: 0.8625 - val_loss: 0.7112 - learning_rate: 5.0000e-05
# Epoch 5/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.8756 - loss: 0.6744 - val_accuracy: 0.8560 - val_loss: 0.6864 - learning_rate: 5.0000e-05
# Epoch 6/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.8790 - loss: 0.6355 - val_accuracy: 0.8770 - val_loss: 0.6133 - learning_rate: 5.0000e-05
# Epoch 7/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.8937 - loss: 0.5814 - val_accuracy: 0.8738 - val_loss: 0.5913 - learning_rate: 5.0000e-05
# Epoch 8/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 61s 186ms/step - accuracy: 0.9001 - loss: 0.5553 - val_accuracy: 0.8430 - val_loss: 0.6355 - learning_rate: 5.0000e-05
# Epoch 9/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 61s 187ms/step - accuracy: 0.8976 - loss: 0.5313 - val_accuracy: 0.8673 - val_loss: 0.5792 - learning_rate: 5.0000e-05
# Epoch 10/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 61s 187ms/step - accuracy: 0.8912 - loss: 0.5264 - val_accuracy: 0.8754 - val_loss: 0.5578 - learning_rate: 5.0000e-05
# Epoch 11/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 61s 187ms/step - accuracy: 0.9057 - loss: 0.4979 - val_accuracy: 0.8722 - val_loss: 0.5592 - learning_rate: 5.0000e-05
# Epoch 12/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 61s 186ms/step - accuracy: 0.8841 - loss: 0.5058 - val_accuracy: 0.8706 - val_loss: 0.5444 - learning_rate: 5.0000e-05
# Epoch 13/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 186ms/step - accuracy: 0.9075 - loss: 0.4739 - val_accuracy: 0.8754 - val_loss: 0.5104 - learning_rate: 5.0000e-05
# Epoch 14/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 186ms/step - accuracy: 0.9115 - loss: 0.4695 - val_accuracy: 0.8851 - val_loss: 0.4958 - learning_rate: 5.0000e-05
# Epoch 15/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 186ms/step - accuracy: 0.9062 - loss: 0.4528 - val_accuracy: 0.8706 - val_loss: 0.5136 - learning_rate: 5.0000e-05
# Epoch 16/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 186ms/step - accuracy: 0.9049 - loss: 0.4611 - val_accuracy: 0.7783 - val_loss: 0.7039 - learning_rate: 5.0000e-05
# Epoch 17/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 186ms/step - accuracy: 0.9068 - loss: 0.4378 - val_accuracy: 0.8819 - val_loss: 0.4845 - learning_rate: 5.0000e-05
# Epoch 18/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9013 - loss: 0.4384 - val_accuracy: 0.8835 - val_loss: 0.4794 - learning_rate: 5.0000e-05
# Epoch 19/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9106 - loss: 0.4186 - val_accuracy: 0.8770 - val_loss: 0.4754 - learning_rate: 5.0000e-05
# Epoch 20/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9111 - loss: 0.4184 - val_accuracy: 0.8625 - val_loss: 0.4968 - learning_rate: 5.0000e-05
# Epoch 21/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9142 - loss: 0.4035 - val_accuracy: 0.8689 - val_loss: 0.4724 - learning_rate: 5.0000e-05
# Epoch 22/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9047 - loss: 0.4106 - val_accuracy: 0.8754 - val_loss: 0.4504 - learning_rate: 5.0000e-05
# Epoch 23/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9120 - loss: 0.3941 - val_accuracy: 0.8819 - val_loss: 0.4404 - learning_rate: 5.0000e-05
# Epoch 24/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9090 - loss: 0.4068 - val_accuracy: 0.8754 - val_loss: 0.4601 - learning_rate: 5.0000e-05
# Epoch 25/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9151 - loss: 0.3946 - val_accuracy: 0.8883 - val_loss: 0.4458 - learning_rate: 5.0000e-05
# Epoch 26/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9187 - loss: 0.3648 - val_accuracy: 0.8722 - val_loss: 0.4580 - learning_rate: 5.0000e-05
# Epoch 27/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9218 - loss: 0.3688 - val_accuracy: 0.8819 - val_loss: 0.4283 - learning_rate: 2.5000e-05
# Epoch 28/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9084 - loss: 0.3810 - val_accuracy: 0.8803 - val_loss: 0.4311 - learning_rate: 2.5000e-05
# Epoch 29/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9242 - loss: 0.3592 - val_accuracy: 0.8803 - val_loss: 0.4256 - learning_rate: 2.5000e-05
# Epoch 30/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9277 - loss: 0.3485 - val_accuracy: 0.8770 - val_loss: 0.4406 - learning_rate: 2.5000e-05
# Epoch 31/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9257 - loss: 0.3572 - val_accuracy: 0.8786 - val_loss: 0.4363 - learning_rate: 2.5000e-05
# Epoch 32/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9107 - loss: 0.3648 - val_accuracy: 0.8786 - val_loss: 0.4118 - learning_rate: 2.5000e-05
# Epoch 33/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 186ms/step - accuracy: 0.9150 - loss: 0.3572 - val_accuracy: 0.8301 - val_loss: 0.5386 - learning_rate: 2.5000e-05
# Epoch 34/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 186ms/step - accuracy: 0.9181 - loss: 0.3473 - val_accuracy: 0.8803 - val_loss: 0.4260 - learning_rate: 2.5000e-05
# Epoch 35/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9211 - loss: 0.3433 - val_accuracy: 0.8754 - val_loss: 0.4360 - learning_rate: 2.5000e-05
# Epoch 36/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9212 - loss: 0.3430 - val_accuracy: 0.8722 - val_loss: 0.4478 - learning_rate: 1.2500e-05
# Epoch 37/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 61s 188ms/step - accuracy: 0.9335 - loss: 0.3287 - val_accuracy: 0.8819 - val_loss: 0.4256 - learning_rate: 1.2500e-05
# Epoch 38/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 61s 188ms/step - accuracy: 0.9305 - loss: 0.3304 - val_accuracy: 0.8835 - val_loss: 0.4235 - learning_rate: 1.2500e-05
# Epoch 39/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9384 - loss: 0.3231 - val_accuracy: 0.8883 - val_loss: 0.4085 - learning_rate: 6.2500e-06
# Epoch 40/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9283 - loss: 0.3320 - val_accuracy: 0.8835 - val_loss: 0.4142 - learning_rate: 6.2500e-06

# %% [markdown]
# ### Step 2.2: Training loss and testing loss

# %%
plt.plot(cnn_model_history.history["loss"], label="Training Loss")
plt.plot(cnn_model_history.history["val_loss"], label="Testing Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.tight_layout()
plt.savefig("images/Custom_CNN_Training_vs_Testing_Loss")
plt.title("Custom CNN: Training vs Testing Loss")
plt.show()

# %% [markdown]
# Our model appears to have trained decently well, but it is possible towards the end of training we are overfitting. This could be due to the number of iterations used, as we can see that the loss starts to flatten after 10 epochs.

# %% [markdown]
# ### Step 2.3: Model Evaluation

# %%
# Evaluate on test set
test_loss, test_acc = cnn_model.evaluate(test_generator)
print(f"Test Accuracy: {test_acc:.4f}")

# Get Predictions
y_pred_probs = cnn_model.predict(test_generator)
y_pred = (y_pred_probs > 0.5).astype(int).ravel()  # Convert to binary labels (0 or 1)

# Labels are already binary, no need for np.argmax()
y_true = test_generator.labels  # array of 0s and 1s

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(
    cm, annot=True, fmt="d", cmap="Blues",
    xticklabels=["NORMAL", "PNEUMONIA"], 
    yticklabels=["NORMAL", "PNEUMONIA"]
)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.tight_layout()
plt.savefig('images/CNN_Model_Classification_Report.png')
plt.show()

print("CNN Model Classification Report:\n", classification_report(y_true, y_pred))
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.8454 - loss: 0.4947
# Test Accuracy: 0.8835
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step
# CNN Model Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.81      0.84       231
#            1       0.89      0.93      0.91       387
#
#     accuracy                           0.88       618
#    macro avg       0.88      0.87      0.87       618
# weighted avg       0.88      0.88      0.88       618

# %% [markdown]
# Base CNN Accuracy, Precision, Recall, and F1-Score:
#
# - **TP (True Positives - Pneumonia correctly identfied):** 360
# - **FN (False Negatives - Pneumonia misclassified as Normal):** 27
# - **TN (True Negatives - Normal correctly identified):** 186
# - **FP (False Positives - Normal misclassified as Pneumonia):** 45
#
# $\text{Accuracy} = \frac{\text{TP+TN}}{\text{TP+FP+TN+FN}}$
# $ = \frac{360+186}{360+45+186+27} = \frac{546}{618} \approx 0.8835$
#
# $\text{Recall} =  \frac{\text{TP}}{\text{TP+FN}}$
# $ = \frac{360}{360+27}=\frac{360}{387} \approx 0.9302$
#
# $\text{Precision} = \frac{\text{TP}}{\text{TP+FP}}$
# $ = \frac{360}{360+45}=\frac{360}{405} \approx 0.8889$
#
# $\text{F1-Score} = 2 \times \frac{\text{Precision}\times \text{Recall}}{\text{Precision + Recall}}$
# $ = 2 \times \frac{0.8889 \times 0.9302}{0.8889+0.9302} = 2 \times \frac{0.8269}{1.8191} \approx 0.9091$

# %% [markdown]
# This model out performed all of the previous models in terms of precision, F1-score, and accuracy. And took just about the same amount of time to find the best random forest model that performed worse. This also did not require any feature extraction which makes it an attractive candidate for use.

# %% [markdown]
# ## Step 3: Use Pretrained Imagenet CNN: VGG16
#
# ---

# %% [markdown]
# ### Step 3.1: VGG16 Model Information and Architecture
#
# The VGG16 model was built for ImageNet. The architecture is too complex to go into for now, but this is a common pretrained classification CNN. More information on this model can be found [here](https://arxiv.org/abs/1409.1556).
#
# We do add a few layers to the bottom that we used in the first CNN model. This again is to discourage overfitting.

# %%
# Load Pretrained Model (VGG16, Without Fully Connected Layers)
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(256, 256, 3))

# Ensure all layers in the base model are frozen initially
for layer in base_model.layers:
    layer.trainable = False

# Correctly Connect New Fully Connected Layers to the Model Graph
x = base_model.output  # Must be a tensor!
x = Flatten()(x)  # Convert to 1D
x = Dense(256, activation='relu', kernel_regularizer=l2(0.01))(x)
x = Dropout(0.5)(x)
x = Dense(1, activation='sigmoid')(x)

# %%
# Define Pretrained Model
pretrained_model = Model(inputs=base_model.input, outputs=x)

# Compile Model
pretrained_model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

# Train Only the New Layers
pretrained_model_history = pretrained_model.fit(
    train_generator_rgb,
    validation_data=test_generator_rgb,
    epochs=40,
    callbacks=[lr_reduction]
)
# Out:
# Epoch 1/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.7893 - loss: 2.9727
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 57s 174ms/step - accuracy: 0.7895 - loss: 2.9689 - val_accuracy: 0.8689 - val_loss: 0.8135 - learning_rate: 1.0000e-04
# Epoch 2/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 173ms/step - accuracy: 0.9110 - loss: 0.6603 - val_accuracy: 0.8819 - val_loss: 0.6291 - learning_rate: 1.0000e-04
# Epoch 3/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 57s 174ms/step - accuracy: 0.9129 - loss: 0.4714 - val_accuracy: 0.8932 - val_loss: 0.5059 - learning_rate: 1.0000e-04
# Epoch 4/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 179ms/step - accuracy: 0.9380 - loss: 0.3177 - val_accuracy: 0.9078 - val_loss: 0.3622 - learning_rate: 1.0000e-04
# Epoch 5/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9462 - loss: 0.2554 - val_accuracy: 0.9061 - val_loss: 0.3606 - learning_rate: 1.0000e-04
# Epoch 6/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 179ms/step - accuracy: 0.9487 - loss: 0.2265 - val_accuracy: 0.9110 - val_loss: 0.3158 - learning_rate: 1.0000e-04
# Epoch 7/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 173ms/step - accuracy: 0.9356 - loss: 0.2314 - val_accuracy: 0.9094 - val_loss: 0.3179 - learning_rate: 1.0000e-04
# Epoch 8/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 173ms/step - accuracy: 0.9509 - loss: 0.2087 - val_accuracy: 0.8948 - val_loss: 0.3651 - learning_rate: 1.0000e-04
# Epoch 9/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 172ms/step - accuracy: 0.9529 - loss: 0.1855 - val_accuracy: 0.9029 - val_loss: 0.3569 - learning_rate: 1.0000e-04
# Epoch 10/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 173ms/step - accuracy: 0.9407 - loss: 0.2009 - val_accuracy: 0.9061 - val_loss: 0.3404 - learning_rate: 5.0000e-05
# Epoch 11/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 173ms/step - accuracy: 0.9534 - loss: 0.1705 - val_accuracy: 0.9207 - val_loss: 0.2707 - learning_rate: 5.0000e-05
# Epoch 12/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 177ms/step - accuracy: 0.9597 - loss: 0.1528 - val_accuracy: 0.9175 - val_loss: 0.2956 - learning_rate: 5.0000e-05
# Epoch 13/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 172ms/step - accuracy: 0.9600 - loss: 0.1548 - val_accuracy: 0.9207 - val_loss: 0.2719 - learning_rate: 5.0000e-05
# Epoch 14/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 172ms/step - accuracy: 0.9589 - loss: 0.1558 - val_accuracy: 0.9175 - val_loss: 0.2931 - learning_rate: 5.0000e-05
# Epoch 15/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 173ms/step - accuracy: 0.9631 - loss: 0.1375 - val_accuracy: 0.9256 - val_loss: 0.2731 - learning_rate: 2.5000e-05
# Epoch 16/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 172ms/step - accuracy: 0.9738 - loss: 0.1305 - val_accuracy: 0.9078 - val_loss: 0.2995 - learning_rate: 2.5000e-05
# Epoch 17/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 172ms/step - accuracy: 0.9683 - loss: 0.1405 - val_accuracy: 0.9191 - val_loss: 0.2728 - learning_rate: 2.5000e-05
# Epoch 18/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 173ms/step - accuracy: 0.9652 - loss: 0.1350 - val_accuracy: 0.9175 - val_loss: 0.2815 - learning_rate: 1.2500e-05
# Epoch 19/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 173ms/step - accuracy: 0.9700 - loss: 0.1299 - val_accuracy: 0.9223 - val_loss: 0.2729 - learning_rate: 1.2500e-05
# Epoch 20/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 173ms/step - accuracy: 0.9717 - loss: 0.1298 - val_accuracy: 0.9223 - val_loss: 0.2575 - learning_rate: 1.2500e-05
# Epoch 21/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 173ms/step - accuracy: 0.9660 - loss: 0.1328 - val_accuracy: 0.9207 - val_loss: 0.2801 - learning_rate: 1.2500e-05
# Epoch 22/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 173ms/step - accuracy: 0.9746 - loss: 0.1223 - val_accuracy: 0.9207 - val_loss: 0.2733 - learning_rate: 1.2500e-05
# Epoch 23/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 173ms/step - accuracy: 0.9688 - loss: 0.1242 - val_accuracy: 0.9207 - val_loss: 0.2686 - learning_rate: 1.2500e-05
# Epoch 24/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 173ms/step - accuracy: 0.9747 - loss: 0.1160 - val_accuracy: 0.9142 - val_loss: 0.2885 - learning_rate: 6.2500e-06
# Epoch 25/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 173ms/step - accuracy: 0.9678 - loss: 0.1289 - val_accuracy: 0.9256 - val_loss: 0.2600 - learning_rate: 6.2500e-06
# Epoch 26/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 173ms/step - accuracy: 0.9738 - loss: 0.1185 - val_accuracy: 0.9207 - val_loss: 0.2681 - learning_rate: 6.2500e-06
# Epoch 27/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 173ms/step - accuracy: 0.9796 - loss: 0.1116 - val_accuracy: 0.9223 - val_loss: 0.2709 - learning_rate: 3.1250e-06
# Epoch 28/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 173ms/step - accuracy: 0.9768 - loss: 0.1170 - val_accuracy: 0.9078 - val_loss: 0.2891 - learning_rate: 3.1250e-06
# Epoch 29/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 173ms/step - accuracy: 0.9713 - loss: 0.1219 - val_accuracy: 0.9207 - val_loss: 0.2682 - learning_rate: 3.1250e-06
# Epoch 30/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 173ms/step - accuracy: 0.9684 - loss: 0.1260 - val_accuracy: 0.9175 - val_loss: 0.2764 - learning_rate: 1.5625e-06
# Epoch 31/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 173ms/step - accuracy: 0.9701 - loss: 0.1266 - val_accuracy: 0.9207 - val_loss: 0.2701 - learning_rate: 1.5625e-06
# Epoch 32/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 173ms/step - accuracy: 0.9754 - loss: 0.1141 - val_accuracy: 0.9175 - val_loss: 0.2773 - learning_rate: 1.5625e-06
# Epoch 33/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 57s 173ms/step - accuracy: 0.9709 - loss: 0.1244 - val_accuracy: 0.9207 - val_loss: 0.2737 - learning_rate: 1.0000e-06
# Epoch 34/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 173ms/step - accuracy: 0.9718 - loss: 0.1236 - val_accuracy: 0.9207 - val_loss: 0.2665 - learning_rate: 1.0000e-06
# Epoch 35/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 173ms/step - accuracy: 0.9719 - loss: 0.1164 - val_accuracy: 0.9191 - val_loss: 0.2739 - learning_rate: 1.0000e-06
# Epoch 36/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 173ms/step - accuracy: 0.9724 - loss: 0.1240 - val_accuracy: 0.9207 - val_loss: 0.2724 - learning_rate: 1.0000e-06
# Epoch 37/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 173ms/step - accuracy: 0.9712 - loss: 0.1235 - val_accuracy: 0.9207 - val_loss: 0.2673 - learning_rate: 1.0000e-06
# Epoch 38/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 173ms/step - accuracy: 0.9697 - loss: 0.1237 - val_accuracy: 0.9207 - val_loss: 0.2738 - learning_rate: 1.0000e-06
# Epoch 39/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 56s 173ms/step - accuracy: 0.9748 - loss: 0.1211 - val_accuracy: 0.9207 - val_loss: 0.2667 - learning_rate: 1.0000e-06
# Epoch 40/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 57s 174ms/step - accuracy: 0.9765 - loss: 0.1142 - val_accuracy: 0.9191 - val_loss: 0.2694 - learning_rate: 1.0000e-06

# %% [markdown]
# ### Step 3.2: Training loss and testing loss

# %%
plt.plot(pretrained_model_history.history["loss"], label="Training Loss")
plt.plot(pretrained_model_history.history["val_loss"], label="Testing Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.title("VGG16: Training vs Testing Loss")
plt.tight_layout()
plt.savefig("images/VGG16_Training_vs_Testing_Loss.png")
plt.show()

# %% [markdown]
# ### Step 3.3: Fine tuning last 4 layers of VGG16

# %%
# Fine-Tune the Last 4 Layers of VGG16
for layer in base_model.layers[-4:]:  # Unfreeze last 4 layers
    layer.trainable = True

# Recompile with Lower Learning Rate
pretrained_model.compile(optimizer=Adam(learning_rate=0.00001), loss='binary_crossentropy', metrics=['accuracy'])

# Train with Fine-Tuning
pretrained_model_finetuning_history = pretrained_model.fit(
    train_generator_rgb,
    validation_data=test_generator_rgb,
    epochs=40,
    callbacks=[lr_reduction]
)
# Out:
# Epoch 1/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 61s 185ms/step - accuracy: 0.9683 - loss: 0.1205 - val_accuracy: 0.9288 - val_loss: 0.2787 - learning_rate: 1.0000e-05
# Epoch 2/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 184ms/step - accuracy: 0.9714 - loss: 0.1104 - val_accuracy: 0.9337 - val_loss: 0.2731 - learning_rate: 1.0000e-05
# Epoch 3/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9782 - loss: 0.0958 - val_accuracy: 0.9401 - val_loss: 0.2719 - learning_rate: 1.0000e-05
# Epoch 4/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 184ms/step - accuracy: 0.9847 - loss: 0.0832 - val_accuracy: 0.9045 - val_loss: 0.3637 - learning_rate: 1.0000e-05
# Epoch 5/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 184ms/step - accuracy: 0.9834 - loss: 0.0827 - val_accuracy: 0.9353 - val_loss: 0.2542 - learning_rate: 1.0000e-05
# Epoch 6/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 61s 187ms/step - accuracy: 0.9861 - loss: 0.0712 - val_accuracy: 0.9385 - val_loss: 0.2692 - learning_rate: 1.0000e-05
# Epoch 7/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 61s 186ms/step - accuracy: 0.9841 - loss: 0.0755 - val_accuracy: 0.9385 - val_loss: 0.2573 - learning_rate: 1.0000e-05
# Epoch 8/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9868 - loss: 0.0664 - val_accuracy: 0.9401 - val_loss: 0.2504 - learning_rate: 1.0000e-05
# Epoch 9/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 184ms/step - accuracy: 0.9879 - loss: 0.0668 - val_accuracy: 0.9256 - val_loss: 0.3418 - learning_rate: 1.0000e-05
# Epoch 10/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9911 - loss: 0.0559 - val_accuracy: 0.9450 - val_loss: 0.2448 - learning_rate: 1.0000e-05
# Epoch 11/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 186ms/step - accuracy: 0.9890 - loss: 0.0566 - val_accuracy: 0.9353 - val_loss: 0.2609 - learning_rate: 1.0000e-05
# Epoch 12/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 184ms/step - accuracy: 0.9944 - loss: 0.0479 - val_accuracy: 0.9450 - val_loss: 0.2573 - learning_rate: 1.0000e-05
# Epoch 13/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 184ms/step - accuracy: 0.9882 - loss: 0.0590 - val_accuracy: 0.9417 - val_loss: 0.3016 - learning_rate: 1.0000e-05
# Epoch 14/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 184ms/step - accuracy: 0.9904 - loss: 0.0505 - val_accuracy: 0.9401 - val_loss: 0.2996 - learning_rate: 5.0000e-06
# Epoch 15/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 184ms/step - accuracy: 0.9939 - loss: 0.0475 - val_accuracy: 0.9466 - val_loss: 0.2602 - learning_rate: 5.0000e-06
# Epoch 16/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 184ms/step - accuracy: 0.9955 - loss: 0.0401 - val_accuracy: 0.9498 - val_loss: 0.2120 - learning_rate: 5.0000e-06
# Epoch 17/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 184ms/step - accuracy: 0.9927 - loss: 0.0459 - val_accuracy: 0.9482 - val_loss: 0.2322 - learning_rate: 5.0000e-06
# Epoch 18/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9964 - loss: 0.0392 - val_accuracy: 0.9417 - val_loss: 0.2846 - learning_rate: 5.0000e-06
# Epoch 19/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 184ms/step - accuracy: 0.9919 - loss: 0.0470 - val_accuracy: 0.9434 - val_loss: 0.2644 - learning_rate: 5.0000e-06
# Epoch 20/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9955 - loss: 0.0405 - val_accuracy: 0.9450 - val_loss: 0.2956 - learning_rate: 2.5000e-06
# Epoch 21/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 184ms/step - accuracy: 0.9934 - loss: 0.0414 - val_accuracy: 0.9450 - val_loss: 0.2784 - learning_rate: 2.5000e-06
# Epoch 22/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9942 - loss: 0.0392 - val_accuracy: 0.9450 - val_loss: 0.2791 - learning_rate: 2.5000e-06
# Epoch 23/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 184ms/step - accuracy: 0.9967 - loss: 0.0350 - val_accuracy: 0.9450 - val_loss: 0.2977 - learning_rate: 1.2500e-06
# Epoch 24/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 184ms/step - accuracy: 0.9978 - loss: 0.0330 - val_accuracy: 0.9466 - val_loss: 0.2816 - learning_rate: 1.2500e-06
# Epoch 25/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9956 - loss: 0.0368 - val_accuracy: 0.9466 - val_loss: 0.2809 - learning_rate: 1.2500e-06
# Epoch 26/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9978 - loss: 0.0314 - val_accuracy: 0.9498 - val_loss: 0.2677 - learning_rate: 1.0000e-06
# Epoch 27/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 186ms/step - accuracy: 0.9965 - loss: 0.0325 - val_accuracy: 0.9482 - val_loss: 0.2477 - learning_rate: 1.0000e-06
# Epoch 28/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9971 - loss: 0.0321 - val_accuracy: 0.9450 - val_loss: 0.2721 - learning_rate: 1.0000e-06
# Epoch 29/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9968 - loss: 0.0330 - val_accuracy: 0.9450 - val_loss: 0.2586 - learning_rate: 1.0000e-06
# Epoch 30/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9961 - loss: 0.0323 - val_accuracy: 0.9482 - val_loss: 0.2708 - learning_rate: 1.0000e-06
# Epoch 31/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 184ms/step - accuracy: 0.9963 - loss: 0.0327 - val_accuracy: 0.9434 - val_loss: 0.2951 - learning_rate: 1.0000e-06
# Epoch 32/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9968 - loss: 0.0324 - val_accuracy: 0.9417 - val_loss: 0.3117 - learning_rate: 1.0000e-06
# Epoch 33/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9974 - loss: 0.0313 - val_accuracy: 0.9385 - val_loss: 0.3246 - learning_rate: 1.0000e-06
# Epoch 34/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9952 - loss: 0.0346 - val_accuracy: 0.9450 - val_loss: 0.2901 - learning_rate: 1.0000e-06
# Epoch 35/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9975 - loss: 0.0305 - val_accuracy: 0.9369 - val_loss: 0.3354 - learning_rate: 1.0000e-06
# Epoch 36/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9969 - loss: 0.0304 - val_accuracy: 0.9401 - val_loss: 0.3169 - learning_rate: 1.0000e-06
# Epoch 37/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 184ms/step - accuracy: 0.9950 - loss: 0.0332 - val_accuracy: 0.9450 - val_loss: 0.2580 - learning_rate: 1.0000e-06
# Epoch 38/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9971 - loss: 0.0317 - val_accuracy: 0.9466 - val_loss: 0.2831 - learning_rate: 1.0000e-06
# Epoch 39/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9977 - loss: 0.0303 - val_accuracy: 0.9466 - val_loss: 0.2806 - learning_rate: 1.0000e-06
# Epoch 40/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 60s 185ms/step - accuracy: 0.9981 - loss: 0.0292 - val_accuracy: 0.9482 - val_loss: 0.2912 - learning_rate: 1.0000e-06

# %% [markdown]
# ### Step 3.4: Fine-tuning training loss and testing loss

# %%
plt.plot(pretrained_model_finetuning_history.history["loss"], label="Training Loss")
plt.plot(pretrained_model_finetuning_history.history["val_loss"], label="Testing Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.title("VGG16 Fine-tuning: Training vs Testing Loss")
plt.tight_layout()
plt.savefig("images/VGG16_Fine-tuning_Training_vs_Testing_Loss.png")
plt.show()

# %% [markdown]
# ### Step 3.5: Model Evaluation

# %%
# Evaluate on test set
test_loss_vgg16, test_acc_vgg16 = pretrained_model.evaluate(test_generator_rgb)
print(f"Test Accuracy: {test_acc_vgg16:.4f}")

# Get Predictions
y_pred_probs_vgg16 = pretrained_model.predict(test_generator_rgb)
y_pred_vgg16 = (y_pred_probs_vgg16 > 0.5).astype(int).ravel()  # Convert to binary labels (0 or 1)

# Labels are already binary, no need for np.argmax()
y_true = test_generator.labels  # array of 0s and 1s

cm_vgg16 = confusion_matrix(y_true, y_pred_vgg16)
plt.figure(figsize=(6,5))
sns.heatmap(
    cm_vgg16, annot=True, fmt="d", cmap="Blues",
    xticklabels=["NORMAL", "PNEUMONIA"], 
    yticklabels=["NORMAL", "PNEUMONIA"]
)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.tight_layout()
plt.savefig('images/VGG16_Model_Classification_Report.png')
plt.show()

print("CNN Model Classification Report:\n", classification_report(y_true, y_pred_vgg16))
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 5s 126ms/step - accuracy: 0.9180 - loss: 0.4544
# Test Accuracy: 0.9482
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step
# CNN Model Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.89      0.93       231
#            1       0.94      0.98      0.96       387
#
#     accuracy                           0.95       618
#    macro avg       0.95      0.94      0.94       618
# weighted avg       0.95      0.95      0.95       618

# %% [markdown]
# VGG16 CNN Accuracy, Precision, Recall, and F1-Score:
#
# - **TP (True Positives - Pneumonia correctly identfied):** 381
# - **FN (False Negatives - Pneumonia misclassified as Normal):** 6
# - **TN (True Negatives - Normal correctly identified):** 205
# - **FP (False Positives - Normal misclassified as Pneumonia):** 26
#
# $\text{Accuracy} = \frac{\text{TP+TN}}{\text{TP+FP+TN+FN}}$
# $ = \frac{381+205}{381+26+205+6} = \frac{586}{618} \approx 0.9482$
#
# $\text{Recall} =  \frac{\text{TP}}{\text{TP+FN}}$
# $ = \frac{381}{381+6}=\frac{381}{387} \approx 0.9845$
#
# $\text{Precision} = \frac{\text{TP}}{\text{TP+FP}}$
# $ = \frac{381}{381+26}=\frac{381}{407} \approx 0.9361$
#
# $\text{F1-Score} = 2 \times \frac{\text{Precision}\times \text{Recall}}{\text{Precision + Recall}}$
# $ = 2 \times \frac{0.9361 \times 0.9845}{0.9361+0.9845} = 2 \times \frac{0.9216}{1.9206} \approx 0.9597$

# %% [markdown]
# ## Step 4: Use Pretrained Imagenet CNN: DenseNet121
#
# ---

# %%
# Load Pretrained DenseNet121 (Without Fully Connected Layers)
base_model_densenet = DenseNet121(weights="imagenet", include_top=False, input_shape=(256, 256, 3))

# Freeze all layers in the base model
for layer in base_model_densenet.layers:
    layer.trainable = False

# Add Custom Fully Connected Layers
x = base_model_densenet.output
x = GlobalAveragePooling2D()(x)  # Use Global Average Pooling instead of Flatten
x = Dense(256, activation='relu', kernel_regularizer=l2(0.01))(x)
x = Dropout(0.5)(x)
x = Dense(1, activation='sigmoid')(x) 

# Define the new model
densenet_model = Model(inputs=base_model_densenet.input, outputs=x)

# Compile Model
densenet_model.compile(optimizer=Adam(learning_rate=0.00005), loss="binary_crossentropy", metrics=["accuracy"])

# %%
# Train Only the New Layers
densenet_model_history = densenet_model.fit(
    train_generator_rgb,
    validation_data=test_generator_rgb,
    epochs=40,
    callbacks=[lr_reduction]
)
# Out:
# Epoch 1/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 69s 192ms/step - accuracy: 0.7163 - loss: 4.2971 - val_accuracy: 0.8042 - val_loss: 2.9564 - learning_rate: 5.0000e-05
# Epoch 2/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 177ms/step - accuracy: 0.8520 - loss: 2.6238 - val_accuracy: 0.8350 - val_loss: 2.0274 - learning_rate: 5.0000e-05
# Epoch 3/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 57s 176ms/step - accuracy: 0.8989 - loss: 1.7604 - val_accuracy: 0.8560 - val_loss: 1.5120 - learning_rate: 5.0000e-05
# Epoch 4/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 177ms/step - accuracy: 0.9146 - loss: 1.3034 - val_accuracy: 0.8479 - val_loss: 1.2438 - learning_rate: 5.0000e-05
# Epoch 5/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 177ms/step - accuracy: 0.9246 - loss: 1.0200 - val_accuracy: 0.8511 - val_loss: 1.0704 - learning_rate: 5.0000e-05
# Epoch 6/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 57s 176ms/step - accuracy: 0.9229 - loss: 0.8631 - val_accuracy: 0.8430 - val_loss: 0.9908 - learning_rate: 5.0000e-05
# Epoch 7/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 177ms/step - accuracy: 0.9330 - loss: 0.7482 - val_accuracy: 0.8430 - val_loss: 0.9194 - learning_rate: 5.0000e-05
# Epoch 8/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 177ms/step - accuracy: 0.9424 - loss: 0.6651 - val_accuracy: 0.8608 - val_loss: 0.8014 - learning_rate: 5.0000e-05
# Epoch 9/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 177ms/step - accuracy: 0.9371 - loss: 0.6045 - val_accuracy: 0.8447 - val_loss: 0.8173 - learning_rate: 5.0000e-05
# Epoch 10/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 57s 177ms/step - accuracy: 0.9433 - loss: 0.5568 - val_accuracy: 0.8463 - val_loss: 0.7517 - learning_rate: 5.0000e-05
# Epoch 11/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 177ms/step - accuracy: 0.9437 - loss: 0.5169 - val_accuracy: 0.8463 - val_loss: 0.7276 - learning_rate: 5.0000e-05
# Epoch 12/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 57s 177ms/step - accuracy: 0.9419 - loss: 0.4829 - val_accuracy: 0.8010 - val_loss: 0.8257 - learning_rate: 5.0000e-05
# Epoch 13/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 177ms/step - accuracy: 0.9450 - loss: 0.4429 - val_accuracy: 0.8673 - val_loss: 0.6169 - learning_rate: 5.0000e-05
# Epoch 14/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 57s 176ms/step - accuracy: 0.9483 - loss: 0.4161 - val_accuracy: 0.8479 - val_loss: 0.6465 - learning_rate: 5.0000e-05
# Epoch 15/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 177ms/step - accuracy: 0.9480 - loss: 0.3959 - val_accuracy: 0.8511 - val_loss: 0.6232 - learning_rate: 5.0000e-05
# Epoch 16/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 57s 176ms/step - accuracy: 0.9482 - loss: 0.3739 - val_accuracy: 0.8528 - val_loss: 0.5910 - learning_rate: 5.0000e-05
# Epoch 17/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 177ms/step - accuracy: 0.9445 - loss: 0.3648 - val_accuracy: 0.8738 - val_loss: 0.5153 - learning_rate: 5.0000e-05
# Epoch 18/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 177ms/step - accuracy: 0.9491 - loss: 0.3348 - val_accuracy: 0.8625 - val_loss: 0.5438 - learning_rate: 5.0000e-05
# Epoch 19/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 178ms/step - accuracy: 0.9514 - loss: 0.3267 - val_accuracy: 0.8576 - val_loss: 0.5387 - learning_rate: 5.0000e-05
# Epoch 20/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 177ms/step - accuracy: 0.9512 - loss: 0.3073 - val_accuracy: 0.8560 - val_loss: 0.5401 - learning_rate: 5.0000e-05
# Epoch 21/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 177ms/step - accuracy: 0.9489 - loss: 0.3011 - val_accuracy: 0.8625 - val_loss: 0.5300 - learning_rate: 2.5000e-05
# Epoch 22/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 177ms/step - accuracy: 0.9558 - loss: 0.2866 - val_accuracy: 0.8430 - val_loss: 0.5686 - learning_rate: 2.5000e-05
# Epoch 23/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 177ms/step - accuracy: 0.9524 - loss: 0.2864 - val_accuracy: 0.8689 - val_loss: 0.4978 - learning_rate: 2.5000e-05
# Epoch 24/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 59s 180ms/step - accuracy: 0.9582 - loss: 0.2763 - val_accuracy: 0.8641 - val_loss: 0.5062 - learning_rate: 2.5000e-05
# Epoch 25/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 59s 180ms/step - accuracy: 0.9509 - loss: 0.2814 - val_accuracy: 0.8544 - val_loss: 0.5155 - learning_rate: 2.5000e-05
# Epoch 26/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 59s 180ms/step - accuracy: 0.9538 - loss: 0.2716 - val_accuracy: 0.8608 - val_loss: 0.5020 - learning_rate: 2.5000e-05
# Epoch 27/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 59s 180ms/step - accuracy: 0.9485 - loss: 0.2740 - val_accuracy: 0.8463 - val_loss: 0.5562 - learning_rate: 1.2500e-05
# Epoch 28/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 179ms/step - accuracy: 0.9560 - loss: 0.2671 - val_accuracy: 0.8576 - val_loss: 0.5043 - learning_rate: 1.2500e-05
# Epoch 29/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 59s 180ms/step - accuracy: 0.9603 - loss: 0.2558 - val_accuracy: 0.8722 - val_loss: 0.4847 - learning_rate: 1.2500e-05
# Epoch 30/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 59s 180ms/step - accuracy: 0.9574 - loss: 0.2545 - val_accuracy: 0.8592 - val_loss: 0.5010 - learning_rate: 1.2500e-05
# Epoch 31/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 179ms/step - accuracy: 0.9540 - loss: 0.2563 - val_accuracy: 0.8592 - val_loss: 0.5064 - learning_rate: 1.2500e-05
# Epoch 32/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 59s 180ms/step - accuracy: 0.9454 - loss: 0.2648 - val_accuracy: 0.8576 - val_loss: 0.5042 - learning_rate: 1.2500e-05
# Epoch 33/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 59s 180ms/step - accuracy: 0.9556 - loss: 0.2511 - val_accuracy: 0.8430 - val_loss: 0.5287 - learning_rate: 6.2500e-06
# Epoch 34/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 59s 180ms/step - accuracy: 0.9528 - loss: 0.2523 - val_accuracy: 0.8576 - val_loss: 0.4925 - learning_rate: 6.2500e-06
# Epoch 35/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 180ms/step - accuracy: 0.9561 - loss: 0.2518 - val_accuracy: 0.8576 - val_loss: 0.4950 - learning_rate: 6.2500e-06
# Epoch 36/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 59s 180ms/step - accuracy: 0.9586 - loss: 0.2524 - val_accuracy: 0.8560 - val_loss: 0.5023 - learning_rate: 3.1250e-06
# Epoch 37/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 179ms/step - accuracy: 0.9552 - loss: 0.2508 - val_accuracy: 0.8592 - val_loss: 0.4980 - learning_rate: 3.1250e-06
# Epoch 38/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 179ms/step - accuracy: 0.9554 - loss: 0.2546 - val_accuracy: 0.8592 - val_loss: 0.4983 - learning_rate: 3.1250e-06
# Epoch 39/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 59s 180ms/step - accuracy: 0.9573 - loss: 0.2473 - val_accuracy: 0.8576 - val_loss: 0.4914 - learning_rate: 1.5625e-06
# Epoch 40/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 59s 182ms/step - accuracy: 0.9591 - loss: 0.2501 - val_accuracy: 0.8560 - val_loss: 0.4999 - learning_rate: 1.5625e-06

# %%
plt.plot(densenet_model_history.history["loss"], label="Training Loss")
plt.plot(densenet_model_history.history["val_loss"], label="Testing Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.title("DenseNet121: Training vs Testing Loss")
plt.tight_layout()
plt.savefig("images/DenseNet121_Training_vs_Testing_Loss.png")
plt.show()

# %%
# Fine-Tune the Last 4 Layers of VGG16
for layer in base_model_densenet.layers[-4:]:  # Unfreeze last 4 layers
    layer.trainable = True

# Recompile with Lower Learning Rate
densenet_model.compile(optimizer=Adam(learning_rate=0.00001), loss='binary_crossentropy', metrics=['accuracy'])

# Train with Fine-Tuning
densenet_model_finetuning_history = densenet_model.fit(
    train_generator_rgb,
    validation_data=test_generator_rgb,
    epochs=40,
    callbacks=[lr_reduction]
)
# Out:
# Epoch 1/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 70s 197ms/step - accuracy: 0.9261 - loss: 0.3134 - val_accuracy: 0.8770 - val_loss: 0.4331 - learning_rate: 1.0000e-05
# Epoch 2/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 59s 182ms/step - accuracy: 0.9400 - loss: 0.2736 - val_accuracy: 0.8786 - val_loss: 0.4191 - learning_rate: 1.0000e-05
# Epoch 3/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 59s 180ms/step - accuracy: 0.9502 - loss: 0.2567 - val_accuracy: 0.8689 - val_loss: 0.4675 - learning_rate: 1.0000e-05
# Epoch 4/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 179ms/step - accuracy: 0.9484 - loss: 0.2549 - val_accuracy: 0.8803 - val_loss: 0.4236 - learning_rate: 1.0000e-05
# Epoch 5/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 177ms/step - accuracy: 0.9385 - loss: 0.2738 - val_accuracy: 0.8803 - val_loss: 0.4190 - learning_rate: 1.0000e-05
# Epoch 6/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 179ms/step - accuracy: 0.9405 - loss: 0.2705 - val_accuracy: 0.8803 - val_loss: 0.4163 - learning_rate: 1.0000e-05
# Epoch 7/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 179ms/step - accuracy: 0.9473 - loss: 0.2586 - val_accuracy: 0.8770 - val_loss: 0.4211 - learning_rate: 1.0000e-05
# Epoch 8/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 179ms/step - accuracy: 0.9457 - loss: 0.2663 - val_accuracy: 0.8770 - val_loss: 0.4125 - learning_rate: 1.0000e-05
# Epoch 9/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 179ms/step - accuracy: 0.9504 - loss: 0.2399 - val_accuracy: 0.8819 - val_loss: 0.3989 - learning_rate: 1.0000e-05
# Epoch 10/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 179ms/step - accuracy: 0.9409 - loss: 0.2622 - val_accuracy: 0.8738 - val_loss: 0.4413 - learning_rate: 1.0000e-05
# Epoch 11/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 178ms/step - accuracy: 0.9576 - loss: 0.2311 - val_accuracy: 0.8722 - val_loss: 0.4215 - learning_rate: 1.0000e-05
# Epoch 12/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 178ms/step - accuracy: 0.9469 - loss: 0.2510 - val_accuracy: 0.8754 - val_loss: 0.4215 - learning_rate: 1.0000e-05
# Epoch 13/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 178ms/step - accuracy: 0.9482 - loss: 0.2501 - val_accuracy: 0.8754 - val_loss: 0.4175 - learning_rate: 5.0000e-06
# Epoch 14/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 180ms/step - accuracy: 0.9486 - loss: 0.2394 - val_accuracy: 0.8754 - val_loss: 0.4181 - learning_rate: 5.0000e-06
# Epoch 15/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 178ms/step - accuracy: 0.9547 - loss: 0.2362 - val_accuracy: 0.8754 - val_loss: 0.4166 - learning_rate: 5.0000e-06
# Epoch 16/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 59s 180ms/step - accuracy: 0.9494 - loss: 0.2397 - val_accuracy: 0.8803 - val_loss: 0.4037 - learning_rate: 2.5000e-06
# Epoch 17/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 59s 182ms/step - accuracy: 0.9529 - loss: 0.2324 - val_accuracy: 0.8722 - val_loss: 0.4096 - learning_rate: 2.5000e-06
# Epoch 18/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 59s 180ms/step - accuracy: 0.9522 - loss: 0.2380 - val_accuracy: 0.8754 - val_loss: 0.4049 - learning_rate: 2.5000e-06
# Epoch 19/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 179ms/step - accuracy: 0.9521 - loss: 0.2368 - val_accuracy: 0.8754 - val_loss: 0.4154 - learning_rate: 1.2500e-06
# Epoch 20/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 179ms/step - accuracy: 0.9525 - loss: 0.2364 - val_accuracy: 0.8754 - val_loss: 0.4141 - learning_rate: 1.2500e-06
# Epoch 21/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 178ms/step - accuracy: 0.9527 - loss: 0.2325 - val_accuracy: 0.8803 - val_loss: 0.4000 - learning_rate: 1.2500e-06
# Epoch 22/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 179ms/step - accuracy: 0.9559 - loss: 0.2321 - val_accuracy: 0.8754 - val_loss: 0.4054 - learning_rate: 1.0000e-06
# Epoch 23/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 179ms/step - accuracy: 0.9483 - loss: 0.2390 - val_accuracy: 0.8738 - val_loss: 0.4093 - learning_rate: 1.0000e-06
# Epoch 24/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 179ms/step - accuracy: 0.9506 - loss: 0.2343 - val_accuracy: 0.8786 - val_loss: 0.4038 - learning_rate: 1.0000e-06
# Epoch 25/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 178ms/step - accuracy: 0.9556 - loss: 0.2361 - val_accuracy: 0.8754 - val_loss: 0.4057 - learning_rate: 1.0000e-06
# Epoch 26/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 178ms/step - accuracy: 0.9528 - loss: 0.2390 - val_accuracy: 0.8770 - val_loss: 0.4050 - learning_rate: 1.0000e-06
# Epoch 27/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 178ms/step - accuracy: 0.9537 - loss: 0.2380 - val_accuracy: 0.8786 - val_loss: 0.4025 - learning_rate: 1.0000e-06
# Epoch 28/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 178ms/step - accuracy: 0.9619 - loss: 0.2187 - val_accuracy: 0.8754 - val_loss: 0.4099 - learning_rate: 1.0000e-06
# Epoch 29/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 179ms/step - accuracy: 0.9504 - loss: 0.2384 - val_accuracy: 0.8786 - val_loss: 0.4020 - learning_rate: 1.0000e-06
# Epoch 30/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 178ms/step - accuracy: 0.9445 - loss: 0.2466 - val_accuracy: 0.8803 - val_loss: 0.4006 - learning_rate: 1.0000e-06
# Epoch 31/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 178ms/step - accuracy: 0.9515 - loss: 0.2360 - val_accuracy: 0.8786 - val_loss: 0.4022 - learning_rate: 1.0000e-06
# Epoch 32/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 179ms/step - accuracy: 0.9587 - loss: 0.2230 - val_accuracy: 0.8803 - val_loss: 0.3924 - learning_rate: 1.0000e-06
# Epoch 33/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 178ms/step - accuracy: 0.9502 - loss: 0.2337 - val_accuracy: 0.8754 - val_loss: 0.4060 - learning_rate: 1.0000e-06
# Epoch 34/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 178ms/step - accuracy: 0.9508 - loss: 0.2390 - val_accuracy: 0.8754 - val_loss: 0.4104 - learning_rate: 1.0000e-06
# Epoch 35/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 178ms/step - accuracy: 0.9537 - loss: 0.2232 - val_accuracy: 0.8754 - val_loss: 0.4087 - learning_rate: 1.0000e-06
# Epoch 36/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 178ms/step - accuracy: 0.9506 - loss: 0.2350 - val_accuracy: 0.8786 - val_loss: 0.4011 - learning_rate: 1.0000e-06
# Epoch 37/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 178ms/step - accuracy: 0.9426 - loss: 0.2441 - val_accuracy: 0.8754 - val_loss: 0.4100 - learning_rate: 1.0000e-06
# Epoch 38/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 178ms/step - accuracy: 0.9460 - loss: 0.2402 - val_accuracy: 0.8770 - val_loss: 0.4060 - learning_rate: 1.0000e-06
# Epoch 39/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 178ms/step - accuracy: 0.9432 - loss: 0.2447 - val_accuracy: 0.8770 - val_loss: 0.4043 - learning_rate: 1.0000e-06
# Epoch 40/40
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 58s 178ms/step - accuracy: 0.9568 - loss: 0.2254 - val_accuracy: 0.8786 - val_loss: 0.4004 - learning_rate: 1.0000e-06

# %%
plt.plot(densenet_model_finetuning_history.history["loss"], label="Training Loss")
plt.plot(densenet_model_finetuning_history.history["val_loss"], label="Testing Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.title("DenseNet121 Fine-tuning: Training vs Testing Loss")
plt.tight_layout()
plt.savefig("images/DenseNet121_Fine-tuning_Training_vs_Testing_Loss.png")
plt.show()

# %%
# Evaluate on test set
test_loss_densenet, test_acc_densenet = densenet_model.evaluate(test_generator_rgb)
print(f"Test Accuracy: {test_acc_densenet:.4f}")

# Get Predictions
y_pred_probs_densenet = densenet_model.predict(test_generator_rgb)
y_pred_densenet = (y_pred_probs_densenet > 0.5).astype(int).ravel()  # Convert to binary labels (0 or 1)

y_true = test_generator.labels  # array of 0s and 1s

cm_densenet = confusion_matrix(y_true, y_pred_densenet)
plt.figure(figsize=(6,5))
sns.heatmap(
    cm_densenet, annot=True, fmt="d", cmap="Blues",
    xticklabels=["NORMAL", "PNEUMONIA"], 
    yticklabels=["NORMAL", "PNEUMONIA"]
)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.tight_layout()
plt.savefig('images/DenseNet121_Model_Classification_Report.png')
plt.show()

print("CNN Model Classification Report:\n", classification_report(y_true, y_pred_densenet))
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.7943 - loss: 0.5858
# Test Accuracy: 0.8786
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step
# CNN Model Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.73      0.82       231
#            1       0.86      0.97      0.91       387
#
#     accuracy                           0.88       618
#    macro avg       0.89      0.85      0.86       618
# weighted avg       0.88      0.88      0.88       618

# %% [markdown]
# DenseNet121 CNN Accuracy, Precision, Recall, and F1-Score:
#
# - **TP (True Positives - Pneumonia correctly identfied):** 374
# - **FN (False Negatives - Pneumonia misclassified as Normal):** 13
# - **TN (True Negatives - Normal correctly identified):** 169
# - **FP (False Positives - Normal misclassified as Pneumonia):** 62
#
# $\text{Accuracy} = \frac{\text{TP+TN}}{\text{TP+FP+TN+FN}}$
# $ = \frac{374+169}{374+62+169+13} = \frac{543}{618} \approx 0.8786$
#
# $\text{Recall} =  \frac{\text{TP}}{\text{TP+FN}}$
# $ = \frac{374}{374+13}=\frac{374}{387} \approx 0.9664$
#
# $\text{Precision} = \frac{\text{TP}}{\text{TP+FP}}$
# $ = \frac{374}{374+62}=\frac{374}{436} \approx 0.8578$
#
# $\text{F1-Score} = 2 \times \frac{\text{Precision}\times \text{Recall}}{\text{Precision + Recall}}$
# $ = 2 \times \frac{0.8578 \times 0.9664}{0.8578+0.9664} = 2 \times \frac{0.8290}{1.8242} \approx 0.9089$

# %% [markdown]
# ## Step 5: Evaluate Best Model
#
# ---

# %%
# Evaluate on test set
test_loss_vgg16, test_acc_vgg16 = pretrained_model.evaluate(test_generator_rgb)
print(f"Test Accuracy: {test_acc_vgg16:.4f}")

# Get Predictions
y_pred_probs_vgg16 = pretrained_model.predict(test_generator_rgb)
y_pred_vgg16 = (y_pred_probs_vgg16 > 0.5).astype(int).ravel()  # Convert to binary labels (0 or 1)

y_true = test_generator.labels  # array of 0s and 1s

cm_vgg16 = confusion_matrix(y_true, y_pred_vgg16)
plt.figure(figsize=(6,5))
sns.heatmap(
    cm_vgg16, annot=True, fmt="d", cmap="Blues",
    xticklabels=["NORMAL", "PNEUMONIA"], 
    yticklabels=["NORMAL", "PNEUMONIA"]
)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

print("CNN Model Classification Report:\n", classification_report(y_true, y_pred_vgg16))
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 5s 126ms/step - accuracy: 0.9180 - loss: 0.4544
# Test Accuracy: 0.9482
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step
# CNN Model Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.89      0.93       231
#            1       0.94      0.98      0.96       387
#
#     accuracy                           0.95       618
#    macro avg       0.95      0.94      0.94       618
# weighted avg       0.95      0.95      0.95       618

# %% [markdown]
# VGG16 CNN Accuracy, Precision, Recall, and F1-Score:
#
# - **TP (True Positives - Pneumonia correctly identfied):** 381
# - **FN (False Negatives - Pneumonia misclassified as Normal):** 6
# - **TN (True Negatives - Normal correctly identified):** 205
# - **FP (False Positives - Normal misclassified as Pneumonia):** 26
#
# $\text{Accuracy} = \frac{\text{TP+TN}}{\text{TP+FP+TN+FN}}$
# $ = \frac{381+205}{381+26+205+6} = \frac{586}{618} \approx 0.9482$
#
# $\text{Recall} =  \frac{\text{TP}}{\text{TP+FN}}$
# $ = \frac{381}{381+6}=\frac{381}{387} \approx 0.9845$
#
# $\text{Precision} = \frac{\text{TP}}{\text{TP+FP}}$
# $ = \frac{381}{381+26}=\frac{381}{407} \approx 0.9361$
#
# $\text{F1-Score} = 2 \times \frac{\text{Precision}\times \text{Recall}}{\text{Precision + Recall}}$
# $ = 2 \times \frac{0.9361 \times 0.9845}{0.9361+0.9845} = 2 \times \frac{0.9216}{1.9206} \approx 0.9597$

# %%
# Compute AUC
auc_score = roc_auc_score(y_true, y_pred_vgg16)
print(f"AUC-ROC: {auc_score:.3f}")

# Compute points for the ROC curve
fpr, tpr, thresholds = roc_curve(y_true, y_pred_vgg16)

# Plot the ROC curve
plt.figure(figsize=(6,6))
plt.plot(fpr, tpr, label=f"VGG16 (AUC = {auc_score:.3f})", lw=2)
plt.plot([0, 1], [0, 1], linestyle='--', color='red')  # reference line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('VGG16 Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.tight_layout()
plt.savefig("images/VGG16_ROC.png")
plt.show()
# Out:
# AUC-ROC: 0.936

# %% [markdown]
# Our final model was able to achieve an exceptional AUC of 0.936
